# %%
from copy import deepcopy
import gurobipy as gp
from gurobipy import GRB
import torch
import torch.nn as nn
import numpy as np
import os
import math
import time
import random

# %%
from opt_alg.branch_and_bound_framework import BranchAndBoundFramework

# %%
instanceName = '50v-10'
cpt = BranchAndBoundFramework(instanceName, maxIteration=100, OutputFlag = 0, Threads = 1, MIPGap = 0.0, TimeLimit = 300)
cpt.solve()
# Out:
# Read MPS format model from file benchmark/50v-10.mps.gz
# Reading time = 0.01 seconds
# 50v-10: 233 rows, 2013 columns, 2745 nonzeros
# This problem has 1647 integer variables and 0 binary variables.
# The optimal value of LP relaxation is 2879.0656868536717.
# ---------------------------------------------------------------------------------------------------------
# |  Iter  |    Lower Bound   |   Overall Improvement   |    Upper Bound   |  Iter Time  |  Overall Time  |
# ---------------------------------------------------------------------------------------------------------
# |       1|         2882.1282|                  0.1064 |              inf |      0.3084 |         0.5836 |
# |       2|         2882.1282|                  0.1064 |              inf |      0.2946 |         0.8783 |
# |       3|         2882.1282|                  0.1064 |              inf |      0.2963 |         1.1747 |
# ...

# %% [markdown]
# 1. children nodes
# 2. itself
# 3. globally valid if you use all leaf nodes

# %%
instanceName = '50v-10'
cpt = BranchAndBoundFramework(instanceName, maxIteration=100, OutputFlag = 0, Threads = 1, MIPGap = 0.0, TimeLimit = 300, cglpNodeSelectionModel = 'bound-based')
cpt.solve()
# Out:
# Read MPS format model from file benchmark/50v-10.mps.gz
# Reading time = 0.01 seconds
# 50v-10: 233 rows, 2013 columns, 2745 nonzeros
# This problem has 1647 integer variables and 0 binary variables.
# The optimal value of LP relaxation is 2879.0656868536717.
# ---------------------------------------------------------------------------------------------------------
# |  Iter  |    Lower Bound   |   Overall Improvement   |    Upper Bound   |  Iter Time  |  Overall Time  |
# ---------------------------------------------------------------------------------------------------------
# |       1|         2882.1282|                  0.1064 |              inf |      0.5472 |         0.8288 |
# |       2|         2882.1282|                  0.1064 |              inf |      0.5182 |         1.3471 |
# |       3|         2882.1282|                  0.1064 |              inf |      0.5239 |         1.8711 |
# ...

# %%
instanceName = '50v-10'
cpt = BranchAndBoundFramework(instanceName, maxIteration=100, OutputFlag = 0, Threads = 1, MIPGap = 0.0, TimeLimit = 300, nodeSelectionModel='BBR')
cpt.solve()
# Out:
# Read MPS format model from file benchmark/50v-10.mps.gz
# Reading time = 0.01 seconds
# 50v-10: 233 rows, 2013 columns, 2745 nonzeros
# This problem has 1647 integer variables and 0 binary variables.
# The optimal value of LP relaxation is 2879.0656868536717.
# ---------------------------------------------------------------------------------------------------------
# |  Iter  |    Lower Bound   |   Overall Improvement   |    Upper Bound   |  Iter Time  |  Overall Time  |
# ---------------------------------------------------------------------------------------------------------
# |       1|         2885.2011|                  0.2131 |              inf |      0.2913 |         0.5537 |
# |       2|         2885.2011|                  0.2131 |              inf |      0.2787 |         0.8324 |
# |       3|         2888.0303|                  0.3114 |              inf |      0.2826 |         1.1151 |
# ...

# %%
instanceName = '50v-10'
cpt = BranchAndBoundFramework(instanceName, maxIteration=100, OutputFlag = 0, Threads = 1, MIPGap = 0.0, TimeLimit = 300, nodeSelectionModel='BBR', cglpNodeSelectionModel = 'bound-based')
cpt.solve()
# Out:
# Read MPS format model from file benchmark/50v-10.mps.gz
# Reading time = 0.01 seconds
# 50v-10: 233 rows, 2013 columns, 2745 nonzeros
# This problem has 1647 integer variables and 0 binary variables.
# The optimal value of LP relaxation is 2879.0656868536717.
# ---------------------------------------------------------------------------------------------------------
# |  Iter  |    Lower Bound   |   Overall Improvement   |    Upper Bound   |  Iter Time  |  Overall Time  |
# ---------------------------------------------------------------------------------------------------------
# |       1|         2885.2011|                  0.2131 |              inf |      0.5154 |         0.8275 |
# |       2|         2888.0303|                  0.3114 |              inf |      0.5269 |         1.3545 |
# |       3|         2893.0303|                  0.4850 |              inf |      0.5350 |         1.8896 |
# ...
